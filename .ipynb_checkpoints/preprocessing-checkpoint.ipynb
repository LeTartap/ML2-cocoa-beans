# %% [markdown]
# ### Warning! This preprocessing notebook does not convert the dataset to the correct format required for YOLOv11 that we use to train our cocoa_diseases dataset. See notebook 'cocoa_pipeline_Razvan.ipynb' for that.

# %%
import dataset_tools as dtools
import os 
import json
import random
import os 
import shutil

# %%
dtools.download(dataset='Cocoa Diseases', dst_dir='~/dataset-ninja/')
# Out:
# Downloading 'Cocoa Diseases': 100%|██████████| 1.56G/1.56G [00:53<00:00, 31.1MB/s]
# Unpacking 'cocoa-diseases.tar': 100%|██████████| 627/627 [00:16<00:00, 38.61file/s]
# '/home/jovyan/dataset-ninja/cocoa-diseases'

# %% [markdown]
# #### Box coordinates must be in normalized xywh format (from 0 to 1). If your boxes are in pixels, you should divide x_center and width by image width, and y_center and height by image height. Class numbers should be zero-indexed (start with 0):

# %%
annot = "GoodLabels2"
datasetPath = "GoodImages"
def jsonToTxt(pathToAnnots):
    os.makedirs(annot, exist_ok=True)
    for n in os.listdir(pathToAnnots):
        if not n.endswith('.json'):
            continue
        with open(os.path.join(pathToAnnots, n)) as json_file:
            with open(os.path.join(annot, n[:-5] + ".txt"), "w") as txt_file:
                print(n)
                data = json.load(json_file)
                w_img=int(data["size"]["width"])
                h_img=int(data["size"]["height"])
                for nr in data["objects"]:
                    idNum = nr["classId"]
                    points = nr["points"]["exterior"]
                    x_begin=int(points[0][0])
                    y_begin=int(points[0][1])
                    x_end=int(points[1][0])
                    y_end=int(points[1][1])
                    w_box=(x_end-x_begin)/w_img
                    h_box=(y_end-y_begin)/h_img
                    print(f"w_box={w_box} h_box= {h_box}")
                    x_center=x_begin/w_img + w_box/2
                    y_center=y_begin/h_img + h_box/2
                    # write txt file
                    txt_file.write(f"{str(idNum)[-1]} {x_center} {y_center} {w_box} {h_box}\n")
jsonToTxt("../dataset-ninja/cocoa-diseases/all/ann/")
# Out:
# Monilia24.jpg.json
# Sana28.jpg.json
# Monilia16.jpg.json
# Sana33.jpg.json
# Sana53.jpg.json
# Monilia45.jpg.json
# Monilia78.jpg.json
# Monilia77.jpg.json
# Fito96.jpg.json
# Fito105.jpg.json
# Sana93.jpg.json
# Fito67.jpg.json
# Fito100.jpg.json
# Fito101.jpg.json
# Sana80.jpg.json
# Fito5.jpg.json
# Sana5.jpg.json
# Monilia63.jpg.json
# Monilia7.jpg.json
# Sana25.jpg.json
# Monilia23.jpg.json
# Fito75.jpg.json
# Fito36.jpg.json
# Monilia81.jpg.json
# Sana6.jpg.json
# Fito24.jpg.json
# Sana85.jpg.json
# Fito73.jpg.json
# Monilia64.jpg.json
# Monilia101.jpg.json
# Monilia105.jpg.json
# Fito47.jpg.json
# Monilia21.jpg.json
# Sana47.jpg.json
# Sana82.jpg.json
# Monilia96.jpg.json
# Fito85.jpg.json
# Monilia31.jpg.json
# Fito76.jpg.json
# Sana8.jpg.json
# Sana84.jpg.json
# Monilia36.jpg.json
# Fito25.jpg.json
# Monilia22.jpg.json
# Fito99.jpg.json
# Sana52.jpg.json
# Fito106.jpg.json
# Fito107.jpg.json
# Monilia86.jpg.json
# Fito11.jpg.json
# Fito88.jpg.json
# Monilia53.jpg.json
# Monilia40.jpg.json
# Sana72.jpg.json
# Monilia62.jpg.json
# Sana70.jpg.json
# Sana36.jpg.json
# Sana57.jpg.json
# Monilia69.jpg.json
# Sana77.jpg.json
# Fito58.jpg.json
# Sana62.jpg.json
# Fito51.jpg.json
# Fito29.jpg.json
# Monilia34.jpg.json
# Monilia55.jpg.json
# Fito78.jpg.json
# Sana69.jpg.json
# Monilia20.jpg.json
# Monilia19.jpg.json

# %%
def train_test_split(path,labelPath,outputPath,neg_path=None, split = 0.2):
    print("------ PROCESS STARTED -------")

    #exculde files without jpg extension

    files = list(set([name[:-4] for name in os.listdir(path) if name.endswith('.jpg')])) ## removing duplicate names i.e. counting only number of images

    print (f"--- This folder has a total number of {len(files)} images---")
    random.seed(42)
    random.shuffle(files)

    test_size = int(len(files) * split)
    train_size = len(files) - test_size

    ## creating required directories
    train_path_img = outputPath + "images/train/"
    train_path_label = outputPath + "labels/train/"
    val_path_img = outputPath + "images/val/"
    val_path_label = outputPath + "labels/val/"


    os.makedirs(train_path_img, exist_ok = True)
    os.makedirs(train_path_label, exist_ok = True)
    os.makedirs(val_path_img, exist_ok = True)
    os.makedirs(val_path_label, exist_ok = True)



    ### ----------- copying images to train folder
    for filex in files[:train_size]:
      print(filex)
      if filex == 'classes':
          continue
          
      shutil.copy2(path + filex + '.jpg',f"{train_path_img}/" + filex + '.jpg' )
      shutil.copy2(labelPath+"/" + filex + '.jpg'+'.txt', f"{train_path_label}/" + filex + '.txt')



    print(f"------ Training data created with 80% split {len(files[:train_size])} images -------")

    if neg_path:
        neg_images = list(set([name[:-4] for name in os.listdir(neg_path)])) ## removing duplicate names i.e. counting only number of images
        for filex in neg_images:
            shutil.copy2(neg_path+filex+ ".jpg", f"{train_path_img}/" + filex + '.jpg')

        print(f"------ Total  {len(neg_images)} negative images added to the training data -------")

        print(f"------ TOTAL Training data created with {len(files[:train_size]) + len(neg_images)} images -------")



    ### copytin images to validation folder
    for filex in files[train_size:]:
      if filex == 'classes':
          continue
      # print("running")
      shutil.copy2(path + filex + '.jpg', f"{val_path_img}/" + filex + '.jpg' )
      shutil.copy2(labelPath+"/" + filex + '.jpg'+'.txt', f"{val_path_label}/" + filex + '.txt')

    print(f"------ Testing data created with a total of {len(files[train_size:])} images ----------")

    print("------ TASK COMPLETED -------")

train_test_split("../dataset-ninja/cocoa-diseases/all/img/",annot,datasetPath)
# Out:
# ------ PROCESS STARTED -------
# --- This folder has a total number of 312 images---
# Sana73
# Sana6
# Sana14
# Fito89
# Fito88
# Fito81
# Sana86
# Sana75
# Fito4
# Sana3
# Fito43
# Fito16
# Fito96
# Monilia8
# Monilia39
# Monilia5
# Monilia55
# Fito75
# Fito61
# Fito97
# Sana28
# Monilia103
# Monilia29
# Fito24
