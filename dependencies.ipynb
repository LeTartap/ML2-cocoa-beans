# %%
# %pip install dataset-tools
# %pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dataset-tools in /home/jovyan/.local/lib/python3.8/site-packages (0.1.4)
# Requirement already satisfied: supervisely>=6.72.28 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (6.73.251)
# Requirement already satisfied: numpy<2.0.0,>=1.19 in /usr/local/lib/python3.8/dist-packages (from dataset-tools) (1.23.1)
# Requirement already satisfied: requests<3.0.0,>=2.27.1 in /usr/local/lib/python3.8/dist-packages (from dataset-tools) (2.31.0)
# Requirement already satisfied: requests-toolbelt<1.0.0,>=0.9.1 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.62.3 in /usr/local/lib/python3.8/dist-packages (from dataset-tools) (4.66.2)
# Requirement already satisfied: pandas<=1.5.2,>=1.1.3 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (1.5.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.2 in /usr/local/lib/python3.8/dist-packages (from dataset-tools) (3.7.5)
# Requirement already satisfied: scikit-image<1.0.0,>=0.17.1 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (0.21.0)
# Requirement already satisfied: dataframe-image<1.0.0,>=0.1.11 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (0.2.6)
# Requirement already satisfied: inflect>=6.0.0 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (7.4.0)
# Requirement already satisfied: gdown>=4.7.1 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (5.2.0)
# Requirement already satisfied: urllib3==1.26.15 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (1.26.15)
# Requirement already satisfied: geojson>=3.0.0 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (3.1.0)
# Requirement already satisfied: titlecase>=2.4.1 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (2.4.1)
# Requirement already satisfied: pycocotools>=2.0.0 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (2.0.7)
# Requirement already satisfied: memory-profiler==0.61.0 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (0.61.0)
# Requirement already satisfied: Pympler==1.0.1 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (1.0.1)
# Requirement already satisfied: xmltodict==0.13.0 in /home/jovyan/.local/lib/python3.8/site-packages (from dataset-tools) (0.13.0)
# Requirement already satisfied: imagesize==1.4.1 in /usr/local/lib/python3.8/dist-packages (from dataset-tools) (1.4.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from memory-profiler==0.61.0->dataset-tools) (5.9.8)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.8/dist-packages (from dataframe-image<1.0.0,>=0.1.11->dataset-tools) (7.16.3)
# Requirement already satisfied: aiohttp>=3.10.2 in /home/jovyan/.local/lib/python3.8/site-packages (from dataframe-image<1.0.0,>=0.1.11->dataset-tools) (3.10.11)
# Requirement already satisfied: pillow in /home/jovyan/.local/lib/python3.8/site-packages (from dataframe-image<1.0.0,>=0.1.11->dataset-tools) (10.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from dataframe-image<1.0.0,>=0.1.11->dataset-tools) (24.0)
# Requirement already satisfied: mistune in /usr/local/lib/python3.8/dist-packages (from dataframe-image<1.0.0,>=0.1.11->dataset-tools) (3.0.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from dataframe-image<1.0.0,>=0.1.11->dataset-tools) (5.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from dataframe-image<1.0.0,>=0.1.11->dataset-tools) (4.12.3)
# Requirement already satisfied: cssutils in /home/jovyan/.local/lib/python3.8/site-packages (from dataframe-image<1.0.0,>=0.1.11->dataset-tools) (2.11.1)
# Requirement already satisfied: html2image in /home/jovyan/.local/lib/python3.8/site-packages (from dataframe-image<1.0.0,>=0.1.11->dataset-tools) (2.0.5)
# Requirement already satisfied: cssselect in /home/jovyan/.local/lib/python3.8/site-packages (from dataframe-image<1.0.0,>=0.1.11->dataset-tools) (1.2.0)
# Requirement already satisfied: filelock in /home/jovyan/.local/lib/python3.8/site-packages (from gdown>=4.7.1->dataset-tools) (3.16.1)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.8/dist-packages (from inflect>=6.0.0->dataset-tools) (10.2.0)
# Requirement already satisfied: typeguard>=4.0.1 in /home/jovyan/.local/lib/python3.8/site-packages (from inflect>=6.0.0->dataset-tools) (4.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from inflect>=6.0.0->dataset-tools) (4.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.2->dataset-tools) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib<4.0.0,>=3.3.2->dataset-tools) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.2->dataset-tools) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib<4.0.0,>=3.3.2->dataset-tools) (1.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.2->dataset-tools) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.2->dataset-tools) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.2->dataset-tools) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas<=1.5.2,>=1.1.3->dataset-tools) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.27.1->dataset-tools) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.27.1->dataset-tools) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.27.1->dataset-tools) (2019.11.28)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.8/dist-packages (from scikit-image<1.0.0,>=0.17.1->dataset-tools) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.8/dist-packages (from scikit-image<1.0.0,>=0.17.1->dataset-tools) (3.1)
# Requirement already satisfied: imageio>=2.27 in /usr/local/lib/python3.8/dist-packages (from scikit-image<1.0.0,>=0.17.1->dataset-tools) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/jovyan/.local/lib/python3.8/site-packages (from scikit-image<1.0.0,>=0.17.1->dataset-tools) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/jovyan/.local/lib/python3.8/site-packages (from scikit-image<1.0.0,>=0.17.1->dataset-tools) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.2 in /home/jovyan/.local/lib/python3.8/site-packages (from scikit-image<1.0.0,>=0.17.1->dataset-tools) (0.4)
# Requirement already satisfied: cachetools<=5.5.0,>=4.2.3 in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (5.3.3)
# Requirement already satisfied: opencv-python<5.0.0.0,>=4.6.0.66 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (4.10.0.84)
# Requirement already satisfied: PTable<1.0.0,>=0.9.2 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.9.2)
# Requirement already satisfied: protobuf<=3.20.3,>=3.19.5 in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (3.20.3)
# Requirement already satisfied: python-json-logger<3.0.0,>=0.1.11 in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (2.0.7)
# Requirement already satisfied: Shapely<=2.0.2,>=1.7.1 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (2.0.2)
# Requirement already satisfied: bidict<1.0.0,>=0.21.2 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.23.1)
# Requirement already satisfied: varname<1.0.0,>=0.8.1 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.13.5)
# Requirement already satisfied: python-dotenv<=1.0.0,>=0.19.2 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (1.0.0)
# Requirement already satisfied: pynrrd<1.0.0,>=0.4.2 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.4.3)
# Requirement already satisfied: SimpleITK<3.0.0.0,>=2.1.1.2 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (2.4.0)
# Requirement already satisfied: pydicom<3.0.0,>=2.3.0 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (2.4.4)
# Requirement already satisfied: stringcase<2.0.0,>=1.2.0 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (1.2.0)
# Requirement already satisfied: python-magic<1.0.0,>=0.4.25 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.4.27)
# Requirement already satisfied: trimesh<=4.5.0,>=3.11.2 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (4.5.0)
# Requirement already satisfied: uvicorn<1.0.0,>=0.18.2 in /home/jovyan/.local/lib/python3.8/site-packages (from uvicorn[standard]<1.0.0,>=0.18.2->supervisely>=6.72.28->dataset-tools) (0.32.1)
# Requirement already satisfied: pydantic<=2.8.2,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (2.7.0)
# Requirement already satisfied: anyio<=4.2.0,>=3.7.1 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (4.2.0)
# Requirement already satisfied: fastapi<=0.109.0,>=0.79.0 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.109.0)
# Requirement already satisfied: websockets<=13.1,>=10.3 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (13.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.0.3 in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (3.1.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.32 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (1.33)
# Requirement already satisfied: MarkupSafe<3.0.0,>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (2.1.5)
# Requirement already satisfied: arel<1.0.0,>=0.2.0 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.3.0)
# Requirement already satisfied: async-asgi-testclient in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (1.4.11)
# Requirement already satisfied: PyYAML>=5.4.0 in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (6.0.1)
# Requirement already satisfied: distinctipy in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (1.3.4)
# Requirement already satisfied: numerize in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.12)
# Requirement already satisfied: ffmpeg-python==0.2.0 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.2.0)
# Requirement already satisfied: python-multipart<=0.0.12,>=0.0.5 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.0.12)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (3.1.43)
# Requirement already satisfied: giturlparse in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.12.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (13.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (8.1.7)
# Requirement already satisfied: imutils==0.5.4 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.5.4)
# Requirement already satisfied: cacheout==0.14.1 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (0.14.1)
# Requirement already satisfied: jsonschema<=4.20.0,>=2.6.0 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (4.20.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.1.0 in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (2.9.0)
# Requirement already satisfied: zstd in /home/jovyan/.local/lib/python3.8/site-packages (from supervisely>=6.72.28->dataset-tools) (1.5.5.1)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.8/dist-packages (from supervisely>=6.72.28->dataset-tools) (22.1.0)
# Requirement already satisfied: httpx==0.27.2 in /home/jovyan/.local/lib/python3.8/site-packages (from httpx[http2]==0.27.2->supervisely>=6.72.28->dataset-tools) (0.27.2)
# Requirement already satisfied: future in /home/jovyan/.local/lib/python3.8/site-packages (from ffmpeg-python==0.2.0->supervisely>=6.72.28->dataset-tools) (1.0.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.8/dist-packages (from httpx==0.27.2->httpx[http2]==0.27.2->supervisely>=6.72.28->dataset-tools) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/dist-packages (from httpx==0.27.2->httpx[http2]==0.27.2->supervisely>=6.72.28->dataset-tools) (1.3.1)
# Requirement already satisfied: h2<5,>=3 in /home/jovyan/.local/lib/python3.8/site-packages (from httpx[http2]==0.27.2->supervisely>=6.72.28->dataset-tools) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.8/dist-packages (from httpcore==1.*->httpx==0.27.2->httpx[http2]==0.27.2->supervisely>=6.72.28->dataset-tools) (0.14.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/jovyan/.local/lib/python3.8/site-packages (from aiohttp>=3.10.2->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.10.2->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.10.2->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.10.2->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.10.2->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/jovyan/.local/lib/python3.8/site-packages (from aiohttp>=3.10.2->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.10.2->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (4.0.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.8/dist-packages (from anyio<=4.2.0,>=3.7.1->supervisely>=6.72.28->dataset-tools) (1.2.1)
# Requirement already satisfied: starlette==0.* in /home/jovyan/.local/lib/python3.8/site-packages (from arel<1.0.0,>=0.2.0->supervisely>=6.72.28->dataset-tools) (0.35.1)
# Requirement already satisfied: watchfiles==0.* in /home/jovyan/.local/lib/python3.8/site-packages (from arel<1.0.0,>=0.2.0->supervisely>=6.72.28->dataset-tools) (0.24.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib<4.0.0,>=3.3.2->dataset-tools) (3.18.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.8/dist-packages (from jsonpatch<2.0,>=1.32->supervisely>=6.72.28->dataset-tools) (2.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.8/dist-packages (from jsonschema<=4.20.0,>=2.6.0->supervisely>=6.72.28->dataset-tools) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /usr/local/lib/python3.8/dist-packages (from jsonschema<=4.20.0,>=2.6.0->supervisely>=6.72.28->dataset-tools) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.8/dist-packages (from jsonschema<=4.20.0,>=2.6.0->supervisely>=6.72.28->dataset-tools) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from jsonschema<=4.20.0,>=2.6.0->supervisely>=6.72.28->dataset-tools) (0.18.0)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (7.1.0)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (2.17.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (1.2.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (5.14.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from pydantic<=2.8.2,>=1.7.4->supervisely>=6.72.28->dataset-tools) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.8/dist-packages (from pydantic<=2.8.2,>=1.7.4->supervisely>=6.72.28->dataset-tools) (2.18.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.3.2->dataset-tools) (1.14.0)
# Requirement already satisfied: httptools>=0.6.3 in /home/jovyan/.local/lib/python3.8/site-packages (from uvicorn[standard]<1.0.0,>=0.18.2->supervisely>=6.72.28->dataset-tools) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/jovyan/.local/lib/python3.8/site-packages (from uvicorn[standard]<1.0.0,>=0.18.2->supervisely>=6.72.28->dataset-tools) (0.21.0)
# Requirement already satisfied: executing<3.0,>=2.1 in /home/jovyan/.local/lib/python3.8/site-packages (from varname<1.0.0,>=0.8.1->supervisely>=6.72.28->dataset-tools) (2.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.8/dist-packages (from beautifulsoup4->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (2.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from GitPython->supervisely>=6.72.28->dataset-tools) (4.0.11)
# Requirement already satisfied: websocket-client==1.* in /usr/local/lib/python3.8/dist-packages (from html2image->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (1.7.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/jovyan/.local/lib/python3.8/site-packages (from requests[socks]->gdown>=4.7.1->dataset-tools) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.8/dist-packages (from rich->supervisely>=6.72.28->dataset-tools) (3.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach!=5.0.0->nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (0.5.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->GitPython->supervisely>=6.72.28->dataset-tools) (5.0.1)
# Requirement already satisfied: hyperframe<7,>=6.0 in /home/jovyan/.local/lib/python3.8/site-packages (from h2<5,>=3->httpx[http2]==0.27.2->supervisely>=6.72.28->dataset-tools) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /home/jovyan/.local/lib/python3.8/site-packages (from h2<5,>=3->httpx[http2]==0.27.2->supervisely>=6.72.28->dataset-tools) (4.0.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.7->nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py>=2.2.0->rich->supervisely>=6.72.28->dataset-tools) (0.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.8/dist-packages (from nbclient>=0.5.0->nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (7.4.9)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.8/dist-packages (from nbformat>=5.7->nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (2.19.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/jovyan/.local/lib/python3.8/site-packages (from yarl<2.0,>=1.12.0->aiohttp>=3.10.2->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (0.2.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.8/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (1.6.0)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.8/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (24.0.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.8/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=5->dataframe-image<1.0.0,>=0.1.11->dataset-tools) (6.4)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in /home/jovyan/.local/lib/python3.8/site-packages (8.3.48)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (1.23.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (1.13.1+cu116)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (0.14.1+cu116)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: py-cpuinfo in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (1.5.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (2.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.0.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jovyan/.local/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics) (2019.11.28)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.18.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.14.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U ultralytics wandb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in /home/jovyan/.local/lib/python3.8/site-packages (8.3.54)
# Collecting ultralytics
#   Downloading ultralytics-8.3.58-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: wandb in /home/jovyan/.local/lib/python3.8/site-packages (0.19.1)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (1.23.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (1.9.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (1.13.1+cu116)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (0.14.1+cu116)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.8/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: py-cpuinfo in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (1.5.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/jovyan/.local/lib/python3.8/site-packages (from ultralytics) (2.0.13)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.8/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/jovyan/.local/lib/python3.8/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: eval-type-backport in /home/jovyan/.local/lib/python3.8/site-packages (from wandb) (0.2.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.8/dist-packages (from wandb) (4.2.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.8/dist-packages (from wandb) (2.7.0)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/jovyan/.local/lib/python3.8/site-packages (from wandb) (2.19.2)
# Requirement already satisfied: setproctitle in /home/jovyan/.local/lib/python3.8/site-packages (from wandb) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb) (69.5.1)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.8/dist-packages (from wandb) (4.11.0)
# Requirement already satisfied: six>=1.4.0 in /usr/lib/python3/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.14.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.0.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->ultralytics) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from pydantic<3,>=2.6->wandb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.8/dist-packages (from pydantic<3,>=2.6->wandb) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jovyan/.local/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics) (2019.11.28)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.18.1)
# Downloading ultralytics-8.3.58-py3-none-any.whl (905 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 12.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.54
#     Uninstalling ultralytics-8.3.54:
#       Successfully uninstalled ultralytics-8.3.54
#   WARNING: The scripts ultralytics and yolo are installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed ultralytics-8.3.58
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import settings
settings.update({"wandb": True})

# %%
# %pip install sparseml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sparseml
#   Using cached sparseml-1.8.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: sparsezoo>=1.7.0 in /home/jovyan/.local/lib/python3.8/site-packages (from sparseml) (1.8.1)
# Requirement already satisfied: pyyaml>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from sparseml) (6.0.1)
# Requirement already satisfied: numpy<2.0,>=1.17.0 in /usr/local/lib/python3.8/dist-packages (from sparseml) (1.23.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from sparseml) (3.7.5)
# Requirement already satisfied: merge-args>=0.1.0 in /home/jovyan/.local/lib/python3.8/site-packages (from sparseml) (0.1.5)
# Requirement already satisfied: onnx<1.15.0,>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from sparseml) (1.13.1)
# Requirement already satisfied: pandas>=0.25.0 in /home/jovyan/.local/lib/python3.8/site-packages (from sparseml) (1.5.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from sparseml) (24.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from sparseml) (5.9.8)
# Requirement already satisfied: pydantic<2.8.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from sparseml) (2.7.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from sparseml) (2.31.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.8/dist-packages (from sparseml) (1.3.2)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from sparseml) (4.66.2)
# Requirement already satisfied: toposort>=1.0 in /home/jovyan/.local/lib/python3.8/site-packages (from sparseml) (1.10)
# Requirement already satisfied: GPUtil>=1.4.0 in /home/jovyan/.local/lib/python3.8/site-packages (from sparseml) (1.4.0)
# Requirement already satisfied: protobuf<=3.20.3,>=3.12.2 in /usr/local/lib/python3.8/dist-packages (from sparseml) (3.20.3)
# Requirement already satisfied: click!=8.0.0,>=7.1.2 in /usr/local/lib/python3.8/dist-packages (from sparseml) (8.1.7)
# Requirement already satisfied: scipy<1.9.2,>=1.8 in /home/jovyan/.local/lib/python3.8/site-packages (from sparseml) (1.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->sparseml) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.0->sparseml) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->sparseml) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.0->sparseml) (1.0.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/jovyan/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->sparseml) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->sparseml) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->sparseml) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->sparseml) (6.4.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx<1.15.0,>=1.5.0->sparseml) (4.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25.0->sparseml) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from pydantic<2.8.0,>=2.0.0->sparseml) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.8/dist-packages (from pydantic<2.8.0,>=2.0.0->sparseml) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0.0->sparseml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.0.0->sparseml) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jovyan/.local/lib/python3.8/site-packages (from requests>=2.0.0->sparseml) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.0.0->sparseml) (2019.11.28)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24.2->sparseml) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24.2->sparseml) (3.4.0)
# Requirement already satisfied: py-machineid>=0.3.0 in /home/jovyan/.local/lib/python3.8/site-packages (from sparsezoo>=1.7.0->sparseml) (0.7.0)
# Requirement already satisfied: geocoder>=1.38.0 in /home/jovyan/.local/lib/python3.8/site-packages (from sparsezoo>=1.7.0->sparseml) (1.38.1)
# Requirement already satisfied: onnxruntime>=1.0.0 in /home/jovyan/.local/lib/python3.8/site-packages (from sparsezoo>=1.7.0->sparseml) (1.19.2)
# Requirement already satisfied: future in /home/jovyan/.local/lib/python3.8/site-packages (from geocoder>=1.38.0->sparsezoo>=1.7.0->sparseml) (1.0.0)
# Requirement already satisfied: ratelim in /home/jovyan/.local/lib/python3.8/site-packages (from geocoder>=1.38.0->sparsezoo>=1.7.0->sparseml) (0.1.6)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from geocoder>=1.38.0->sparsezoo>=1.7.0->sparseml) (1.14.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->sparseml) (3.18.1)
# Requirement already satisfied: coloredlogs in /home/jovyan/.local/lib/python3.8/site-packages (from onnxruntime>=1.0.0->sparsezoo>=1.7.0->sparseml) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.8/dist-packages (from onnxruntime>=1.0.0->sparsezoo>=1.7.0->sparseml) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from onnxruntime>=1.0.0->sparsezoo>=1.7.0->sparseml) (1.12)
# Requirement already satisfied: humanfriendly>=9.1 in /home/jovyan/.local/lib/python3.8/site-packages (from coloredlogs->onnxruntime>=1.0.0->sparsezoo>=1.7.0->sparseml) (10.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ratelim->geocoder>=1.38.0->sparsezoo>=1.7.0->sparseml) (5.1.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy->onnxruntime>=1.0.0->sparsezoo>=1.7.0->sparseml) (1.3.0)
# Using cached sparseml-1.8.0-py3-none-any.whl (1.3 MB)
# Installing collected packages: sparseml
#   WARNING: The scripts sparseml.evaluate, sparseml.export, sparseml.framework, sparseml.image_classification.export_onnx, sparseml.image_classification.train, sparseml.openpifpaf.export_onnx, sparseml.openpifpaf.train, sparseml.pytorch.image_classification.export_onnx, sparseml.pytorch.image_classification.lr_analysis, sparseml.pytorch.image_classification.pr_sensitivity, sparseml.pytorch.image_classification.train, sparseml.recipe_template, sparseml.sparsification, sparseml.transformers.export_onnx, sparseml.transformers.export_onnx_refactor, sparseml.transformers.masked_language_modeling, sparseml.transformers.question_answering, sparseml.transformers.text_classification, sparseml.transformers.text_generation.apply, sparseml.transformers.text_generation.compress, sparseml.transformers.text_generation.eval, sparseml.transformers.text_generation.finetune, sparseml.transformers.text_generation.oneshot, sparseml.transformers.text_generation.train, sparseml.transformers.token_classification, sparseml.transformers.train.masked_language_modeling, sparseml.transformers.train.question_answering, sparseml.transformers.train.text_classification, sparseml.transformers.train.token_classification, sparseml.ultralytics.export_onnx, sparseml.ultralytics.train, sparseml.ultralytics.val, sparseml.yolact.download, sparseml.yolact.export_onnx, sparseml.yolact.train, sparseml.yolact.validation, sparseml.yolov5.export_onnx, sparseml.yolov5.train and sparseml.yolov5.validation are installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed sparseml-1.8.0
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch-pruning --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch-pruning
#   Downloading torch_pruning-1.5.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from torch-pruning) (1.13.1+cu116)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torch-pruning) (1.23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->torch-pruning) (4.11.0)
# Downloading torch_pruning-1.5.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: torch-pruning
# Successfully installed torch-pruning-1.5.1
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
